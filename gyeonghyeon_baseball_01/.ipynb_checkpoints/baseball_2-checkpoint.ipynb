# %%
import pandas as pd
import numpy as np
import re
import warnings
warnings.filterwarnings('ignore')

# %%
외국인역대성적 = pd.read_csv('kbo_yearly_foreigners_2011_2018.csv')
외국인메이저성적 = pd.read_csv('fangraphs_foreigners_2011_2018.csv')
외국인스탯캐스터 = pd.read_csv('baseball_savant_foreigners_2011_2018.csv')
신규외국인성적 = pd.read_csv('fangraphs_foreigners_2019.csv')
신규외국인스텟캐스터 = pd.read_csv('baseball_savant_foreigners_2019.csv')

# %%
df = pd.read_csv('최종외국인스탯캐스터.csv',encoding='euc-kr',engine="python")
df
# Out:
#          game_date  release_speed    batter  pitcher     events  \
# 0       2010-10-09           93.0  425834.0   430962  field_out
# 1       2010-10-09           95.2  150289.0   430962   home_run
# 2       2010-10-09           94.3  150289.0   430962        NaN
# 3       2010-10-09           94.0  150289.0   430962        NaN
# 4       2010-10-09           92.8  150289.0   430962        NaN
# 5       2010-10-09           80.8  150289.0   430962        NaN
# 6       2010-10-09           92.0  150289.0   430962        NaN
# 7       2010-10-09           92.5  430632.0   430962  field_out
# 8       2010-10-09           91.2  430632.0   430962        NaN
# 9       2010-10-09           91.8  430632.0   430962        NaN
# 10      2010-10-09           72.2  446481.0   430962     single
# 11      2010-10-09           74.9  446481.0   430962        NaN
# 12      2010-10-09           74.9  446334.0   430962  field_out
# 13      2010-10-09           94.8  446334.0   430962        NaN
# 14      2010-10-09           93.0  446334.0   430962        NaN
# 15      2010-10-03           93.6  116338.0   430962  field_out
# 16      2010-10-03           81.8  116338.0   430962        NaN
# 17      2010-10-03           91.0  116338.0   430962        NaN
# 18      2010-10-03           92.9  116338.0   430962        NaN
# 19      2010-10-03           82.0  110029.0   430962  field_out
# 20      2010-10-03           83.3  110029.0   430962        NaN
# 21      2010-10-03           93.4  110029.0   430962        NaN
# 22      2010-10-03           92.7  110029.0   430962        NaN
# 23      2010-10-03           82.5  110029.0   430962        NaN
# 24      2010-10-03           90.5  110029.0   430962        NaN
# 25      2010-10-03           73.7  435062.0   430962  field_out
# 26      2010-10-03           91.7  435062.0   430962        NaN
# 27      2010-10-03           92.3  435062.0   430962        NaN
# 28      2010-10-03           92.3  435062.0   430962        NaN
# 29      2010-10-03           71.5  488721.0   430962   home_run
# ...            ...            ...       ...      ...        ...
# 135723  2017-08-24           90.2  621035.0   605795        NaN
# 135724  2017-08-24           89.2  621035.0   605795        NaN
# 135725  2017-08-24           91.0  621035.0   605795        NaN
# 135726  2017-08-24           89.4  400284.0   605795     double
# 135727  2017-08-24           89.0  400284.0   605795        NaN
# 135728  2017-08-24           95.8  400284.0   605795        NaN
# 135729  2017-08-24           90.0  571771.0   605795  field_out
# 135730  2017-08-24           95.7  571771.0   605795        NaN
# 135731  2017-08-24           90.1  571771.0   605795        NaN
# 135732  2017-08-24           95.3  571771.0   605795        NaN
# 135733  2017-08-24           91.5  571771.0   605795        NaN
# 135734  2017-08-24           90.5  523253.0   605795  field_out
# 135735  2017-08-24           96.8  523253.0   605795        NaN
# 135736  2017-08-24           81.3  523253.0   605795        NaN
# 135737  2017-08-24           91.3  523253.0   605795        NaN
# 135738  2017-08-24           90.4  523253.0   605795        NaN
# 135739  2017-08-24           97.0  523253.0   605795        NaN
# 135740  2017-08-24           82.4  523253.0   605795        NaN
# 135741  2017-08-24           92.4  523253.0   605795        NaN
# 135742  2017-08-24           89.7  624577.0   605795  field_out
# 135743  2017-08-24           82.3  624577.0   605795        NaN
# 135744  2017-08-24           81.5  624577.0   605795        NaN
# 135745  2017-08-24           96.4  408236.0   605795   home_run
# 135746  2017-08-24           92.0  518735.0   605795   home_run
# 135747  2017-08-24           90.4  518735.0   605795        NaN
# 135748  2017-08-24           96.4  518735.0   605795        NaN
# 135749  2017-08-24           91.6  457759.0   605795  field_out
# 135750  2017-08-24           91.9  457759.0   605795        NaN
# 135751  2017-08-24           95.6  457759.0   605795        NaN
# 135752  2017-08-24           95.5  457759.0   605795        NaN
#
#                  description  zone stand p_throws      bb_type  ...        ax  \
# 0              hit_into_play   4.0     R        R        popup  ...   -6.4040
# 1        hit_into_play_score   5.0     L        R     fly_ball  ...  -10.1680
# 2                       foul   2.0     L        R          NaN  ...   -5.6050
# 3               blocked_ball  13.0     L        R          NaN  ...   -9.0990
# 4                       ball  14.0     L        R          NaN  ...   -5.8460
# 5                   foul_tip  13.0     L        R          NaN  ...  -10.8970
# 6                       ball   9.0     L        R          NaN  ...   -6.2510
# 7              hit_into_play  13.0     L        R   line_drive  ...   -8.2790
# 8                       ball  13.0     L        R          NaN  ...   -9.2390
# 9                       ball  11.0     L        R          NaN  ...  -12.0900
# 10      hit_into_play_no_out   3.0     R        R   line_drive  ...    2.2820
# 11                      ball  14.0     R        R          NaN  ...    3.3250
# 12             hit_into_play   3.0     R        R     fly_ball  ...    5.2750
# 13                      ball  12.0     R        R          NaN  ...   -4.9800
# 14             called_strike   1.0     R        R          NaN  ...   -8.0900
# 15             hit_into_play   5.0     R        R     fly_ball  ...   -5.3750
# 16             called_strike  11.0     R        R          NaN  ...  -11.6230
# 17                      ball  13.0     R        R          NaN  ...  -10.8470
# 18                      foul   3.0     R        R          NaN  ...   -4.8070
# 19             hit_into_play  13.0     L        R  ground_ball  ...   -8.8990
# 20                      ball  13.0     L        R          NaN  ...   -9.0560
# 21                      ball  12.0     L        R          NaN  ...   -4.0960
# 22                      foul  11.0     L        R          NaN  ...  -10.2980
# 23                      foul  11.0     L        R          NaN  ...  -11.9160
# 24             called_strike   1.0     L        R          NaN  ...   -7.0820
# 25             hit_into_play   5.0     R        R  ground_ball  ...    2.8300
# 26             called_strike   9.0     R        R          NaN  ...   -7.7740
# 27                      ball  14.0     R        R          NaN  ...   -5.3020
# 28                      ball   6.0     R        R          NaN  ...   -7.6550
# 29       hit_into_play_score   1.0     R        R     fly_ball  ...    3.0060
# ...                      ...   ...   ...      ...          ...  ...       ...
# 135723       swinging_strike   8.0     R        R          NaN  ...  -15.9038
# 135724       swinging_strike  13.0     R        R          NaN  ...  -19.5443
# 135725                  ball  11.0     R        R          NaN  ...   -4.5674
# 135726  hit_into_play_no_out   5.0     L        R  ground_ball  ...  -16.8747
# 135727                  ball  13.0     L        R          NaN  ...  -16.4951
# 135728                  ball  11.0     L        R          NaN  ...  -18.0427
# 135729         hit_into_play   2.0     R        R        popup  ...   -4.6971
# 135730                  ball  12.0     R        R          NaN  ...  -17.7471
# 135731       swinging_strike   5.0     R        R          NaN  ...   -1.3893
# 135732                  ball  12.0     R        R          NaN  ...  -13.5157
# 135733                  ball  14.0     R        R          NaN  ...   -2.6709
# 135734         hit_into_play   5.0     R        R   line_drive  ...    1.6886
# 135735                  foul  12.0     R        R          NaN  ...  -13.5542
# 135736                  ball  13.0     R        R          NaN  ...   -1.9561
# 135737                  ball  11.0     R        R          NaN  ...    1.3555
# 135738                  foul  13.0     R        R          NaN  ...   -1.5178
# 135739         called_strike   3.0     R        R          NaN  ...  -11.8263
# 135740                  ball  11.0     R        R          NaN  ...    0.8628
# 135741         called_strike   9.0     R        R          NaN  ...   -1.7282
# 135742         hit_into_play   6.0     R        R     fly_ball  ...   -0.9872
# 135743                  ball  13.0     R        R          NaN  ...   -0.4621
# 135744                  foul   8.0     R        R          NaN  ...   -0.3993
# 135745   hit_into_play_score   6.0     L        R     fly_ball  ...  -15.0667
# 135746   hit_into_play_score   5.0     L        R     fly_ball  ...   -0.7806
# 135747                  ball  13.0     L        R          NaN  ...  -15.7202
# 135748                  ball  11.0     L        R          NaN  ...  -16.0426
# 135749         hit_into_play   2.0     R        R        popup  ...    1.0209
# 135750         called_strike   8.0     R        R          NaN  ...   -1.7590
# 135751                  ball  11.0     R        R          NaN  ...  -15.6116
# 135752                  ball  11.0     R        R          NaN  ...  -12.4412
#
#              ay       az  launch_speed  launch_angle  release_spin_rate  \
# 0       26.0770  -9.6940           NaN           NaN                NaN
# 1       28.7860  -8.8950           NaN           NaN                NaN
# 2       26.6570  -7.7940           NaN           NaN                NaN
# 3       30.2730  -6.3710           NaN           NaN                NaN
# 4       27.2900 -11.2620           NaN           NaN                NaN
# 5       18.5390 -20.2860           NaN           NaN                NaN
# 6       27.7860 -10.0310           NaN           NaN                NaN
# 7       26.4660  -8.3760           NaN           NaN                NaN
# 8       25.4900 -13.5560           NaN           NaN                NaN
# 9       25.6590 -15.2500           NaN           NaN                NaN
# 10      15.0150 -35.0610           NaN           NaN                NaN
# 11      17.3270 -34.1580           NaN           NaN                NaN
# 12      16.2440 -36.6810           NaN           NaN                NaN
# 13      28.7550 -12.3260           NaN           NaN                NaN
# 14      23.0230 -13.9550           NaN           NaN                NaN
# 15      24.1060  -8.3560           NaN           NaN                NaN
# 16      16.7450 -19.5730           NaN           NaN                NaN
# 17      19.2870 -11.0600           NaN           NaN                NaN
# 18      23.0370  -4.9140           NaN           NaN                NaN
# 19      14.7200 -19.4330           NaN           NaN                NaN
# 20      14.9500 -19.4120           NaN           NaN                NaN
# 21      21.0570  -7.3210           NaN           NaN                NaN
# 22      24.6820  -6.9090           NaN           NaN                NaN
# 23      18.2940 -20.9300           NaN           NaN                NaN
# 24      23.0880  -8.2960           NaN           NaN                NaN
# 25      15.8290 -33.5620           NaN           NaN                NaN
# 26      22.3580  -8.7600           NaN           NaN                NaN
# 27      25.6560  -5.2910           NaN           NaN                NaN
# 28      25.3300  -9.4400           NaN           NaN                NaN
# 29      13.5180 -37.6340           NaN           NaN                NaN
# ...         ...      ...           ...           ...                ...
# 135723  26.0344 -21.6074           NaN           NaN             1851.0
# 135724  23.6801 -22.7134           NaN           NaN             1711.0
# 135725  23.3131 -20.9824           NaN           NaN             2214.0
# 135726  23.6351 -22.3574          97.3           3.0             1803.0
# 135727  24.5270 -25.0227           NaN           NaN             1724.0
# 135728  32.9028 -13.5468           NaN           NaN             2185.0
# 135729  26.0001 -22.5639          83.3          63.0             2292.0
# 135730  29.1835 -17.2903           NaN           NaN             2155.0
# 135731  23.5354 -20.6290           NaN           NaN             2238.0
# 135732  29.1595 -15.1210           NaN           NaN             2164.0
# 135733  26.9071 -19.1538           NaN           NaN             2349.0
# 135734  23.5970 -24.9293          97.8          20.0             2347.0
# 135735  31.5516  -9.6610           NaN           NaN             2319.0
# 135736  22.1426 -39.6401           NaN           NaN             2400.0
# 135737  25.2779 -23.6787           NaN           NaN             2273.0
# 135738  25.6215 -27.7729           NaN           NaN             2260.0
# 135739  31.9071  -9.8918           NaN           NaN             2246.0
# 135740  20.6482 -40.7247           NaN           NaN             2446.0
# 135741  27.3857 -23.4197           NaN           NaN             2286.0
# 135742  22.6445 -26.7113          84.4          46.0             2311.0
# 135743  22.1707 -40.5347           NaN           NaN             2256.0
# 135744  20.1003 -37.5292          63.6         -25.0             2313.0
# 135745  29.6472 -12.1448         100.3          29.0             2224.0
# 135746  26.1343 -20.1105         104.0          26.0             2445.0
# 135747  24.9094 -21.1274           NaN           NaN             1756.0
# 135748  30.7298  -8.6690           NaN           NaN             2322.0
# 135749  24.7374 -21.7554          76.1          62.0             2307.0
# 135750  25.3770 -20.8001           NaN           NaN             2418.0
# 135751  28.6716 -15.3398           NaN           NaN             2283.0
# 135752  29.0825 -14.0942           NaN           NaN             2339.0
#
#              pitch_name  pitcher_name   km변환  type
# 0       4-Seam Fastball           니퍼트  150.0     N
# 1       4-Seam Fastball           니퍼트  153.0     N
# 2       4-Seam Fastball           니퍼트  152.0     S
# 3       4-Seam Fastball           니퍼트  151.0     B
# 4       4-Seam Fastball           니퍼트  149.0     B
# 5              Changeup           니퍼트  130.0     N
# 6       4-Seam Fastball           니퍼트  148.0     B
# 7       4-Seam Fastball           니퍼트  149.0     N
# 8       4-Seam Fastball           니퍼트  147.0     B
# 9       2-Seam Fastball           니퍼트  148.0     B
# 10            Curveball           니퍼트  116.0     N
# 11            Curveball           니퍼트  121.0     B
# 12            Curveball           니퍼트  121.0     N
# 13      4-Seam Fastball           니퍼트  153.0     B
# 14      4-Seam Fastball           니퍼트  150.0     S
# 15      4-Seam Fastball           니퍼트  151.0     N
# 16             Changeup           니퍼트  132.0     S
# 17      4-Seam Fastball           니퍼트  146.0     B
# 18      4-Seam Fastball           니퍼트  150.0     S
# 19             Changeup           니퍼트  132.0     N
# 20             Changeup           니퍼트  134.0     B
# 21      4-Seam Fastball           니퍼트  150.0     B
# 22      4-Seam Fastball           니퍼트  149.0     S
# 23             Changeup           니퍼트  133.0     S
# 24      4-Seam Fastball           니퍼트  146.0     S
# 25            Curveball           니퍼트  119.0     N
# 26      4-Seam Fastball           니퍼트  148.0     S
# 27      4-Seam Fastball           니퍼트  149.0     B
# 28      4-Seam Fastball           니퍼트  149.0     B
# 29            Curveball           니퍼트  115.0     N
# ...                 ...           ...    ...   ...
# 135723         Changeup           산체스  145.0     S
# 135724         Changeup           산체스  144.0     S
# 135725           Cutter           산체스  146.0     B
# 135726         Changeup           산체스  144.0     N
# 135727         Changeup           산체스  143.0     B
# 135728  4-Seam Fastball           산체스  154.0     B
# 135729           Cutter           산체스  145.0     N
# 135730  4-Seam Fastball           산체스  154.0     B
# 135731           Cutter           산체스  145.0     S
# 135732  4-Seam Fastball           산체스  153.0     B
# 135733           Cutter           산체스  147.0     B
# 135734           Cutter           산체스  146.0     N
# 135735  4-Seam Fastball           산체스  156.0     S
# 135736        Curveball           산체스  131.0     B
# 135737           Cutter           산체스  147.0     B
# 135738           Cutter           산체스  145.0     S
# 135739  4-Seam Fastball           산체스  156.0     S
# 135740        Curveball           산체스  133.0     B
# 135741           Cutter           산체스  149.0     S
# 135742           Cutter           산체스  144.0     N
# 135743        Curveball           산체스  132.0     B
# 135744        Curveball           산체스  131.0     S
# 135745  4-Seam Fastball           산체스  155.0     N
# 135746           Cutter           산체스  148.0     N
# 135747         Changeup           산체스  145.0     B
# 135748  4-Seam Fastball           산체스  155.0     B
# 135749           Cutter           산체스  147.0     N
# 135750           Cutter           산체스  148.0     S
# 135751  4-Seam Fastball           산체스  154.0     B
# 135752  4-Seam Fastball           산체스  154.0     B
#
# [135753 rows x 26 columns]

# %%
throw_df = pd.read_csv('plus_win_lose_2.csv')
print(throw_df.shape)
top20 = throw_df.sort_values(['승률','경기수'], ascending=False).reset_index(drop=True)[:20]
# bottom20 = throw_df.sort_values(['승률','경기수'], ascending=False).reset_index(drop=True)[-20:]
# display(top20)
# display(bottom20)
# Out:
# (105, 16)

# %% [markdown]
# ### 머신러닝

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
throw_df['year_born'] = throw_df['year_born'].fillna(0)
throw_df['방출연도'] = throw_df['방출연도'].fillna(0)

# %%
throw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 16 columns):
# pitcher_name    105 non-null object
# year            105 non-null int64
# team            105 non-null object
# ERA             105 non-null float64
# TBF             105 non-null int64
# H               105 non-null int64
# HR              105 non-null int64
# BB              105 non-null int64
# HBP             105 non-null int64
# SO              105 non-null int64
# year_born       105 non-null object
# 승               105 non-null int64
# 패               105 non-null int64
# 승률              105 non-null float64
# 경기수             105 non-null int64
# 방출연도            105 non-null float64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 13.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder

def label(df):
    col = list(df)
    encoder = LabelEncoder()
    encoder.fit(col)
    col_label = encoder.transform(col)
    return col_label

pitcher_name_label = label(throw_df['pitcher_name'])
team_label = label(throw_df['team'])
year_born_label = label(throw_df['year_born'])

# %%
throw_df = throw_df.assign(pitcher_name_label=pitcher_name_label,
                          team_label=team_label,
                          year_born_label=year_born_label)
throw_df_digit = throw_df.drop(['pitcher_name','team','year_born','year'],axis=1)
throw_df_digit.head()
# Out:
#     ERA  TBF    H  HR  BB  HBP   SO   승   패     승률  경기수  방출연도  \
# 0  3.88  719  149  11  84   15  122  11  13  0.458   24   0.0
# 1  2.55  763  150   8  64   10  150  15   6  0.714   21   0.0
# 2  3.20  785  156  15  68    8  126  11  10  0.524   21   0.0
# 3  3.69  656  138   6  68    9  144   5  12  0.294   17   0.0
# 4  3.54  614  137   9  39    8  104   9   8  0.529   17   0.0
#
#    pitcher_name_label  team_label  year_born_label
# 0                   9           2                0
# 1                   0           6                0
# 2                   0           6                0
# 3                   9           2                0
# 4                  25           0                0

# %%
feature = throw_df_digit.drop('승',axis=1)
label = throw_df_digit['승']

# %%
X_train, X_test, y_train, y_test = train_test_split(feature,label, test_size = 0.2, random_state=20)

# %%
base_dtc = DecisionTreeClassifier(random_state=20, criterion='entropy')

# %%
base_dtc.fit(X_train, y_train)
predition = base_dtc.predict(X_test)
